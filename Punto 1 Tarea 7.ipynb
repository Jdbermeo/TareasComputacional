# %%
# %pylab inline
from mpl_toolkits.mplot3d import Axes3D
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['beta']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
n_x = 200
c = 1.0
dx = 2.0/n_x
beta = 0.01
dt = beta*dx 

n_t = int(0.15/dt) 
x = linspace(0, 2.0, n_x)
X = np.array(x)
u = 3.0*sin(pi*x)
t = linspace(0, 0.15, 200)
T = np.array(t)
plot(x,u)

# %%
for n in range(n_t):  # loop over time
    u_past = u.copy() 
    for i in range(1,n_x-1): #loop over space
        u[i] = u_past[i]  - beta*((u_past[i+1])**2-(u_past[i-1])**2)*0.5
  
    U = np.vstack([U, u])
plot(x,u)

# %%
fig = plt.figure()
Axes3D = fig.gca(projection='3d')
ax = fig.add_subplot(111, projection='3d')
X, T = numpy.meshgrid(X, T)
Axes3D.plot_wireframe(X,T,U,rstride=20,cstride=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-89c9e1093b7c> in <module>()
#       2 Axes3D = fig.gca(projection='3d')
#       3 ax = fig.add_subplot(111, projection='3d')
# ----> 4 X, T = numpy.meshgrid(X, T)
#       5 Axes3D.plot_wireframe(X,T,U,rstride=20,cstride=10)
#       6 plt.show()
#
# /usr/lib/python2.7/dist-packages/numpy/lib/function_base.pyc in meshgrid(*xi, **kwargs)
#    3376         # Return the full N-D matrix (not only the 1-D vector)
#    3377         if copy_:
# -> 3378             mult_fact = np.ones(shape, dtype=int)
#    3379             return [x * mult_fact for x in output]
#    3380         else:
#
# /usr/lib/python2.7/dist-packages/numpy/core/numeric.pyc in ones(shape, dtype, order)
#     146
#     147     """
# --> 148     a = empty(shape, dtype, order)
#     149     multiarray.copyto(a, 1, casting='unsafe')
#     150     return a
#
# ValueError: array is too big.

# %%
n_x = 200
c = 1.0
dx = 2.0/n_x
beta = 0.05
dt = beta*dx 
n_t = int(0.15/dt) 
x = linspace(0, 2.0, n_x)
X = np.array(x)
u = 3.0*sin(pi*x)
t = linspace(0, 0.15, n_t)
T = np.array(t)
plot(x,u)
print n_t
# Out:
# 300

# %%
for n in range(n_t):  # loop over time
    u_p = u.copy() 
    for i in range(1,n_x-1): #loop over space
        u[i] = u_p[i] - (beta/4)*((u_p[i+1])**2 - (u_p[i-1])**2) + ((beta**2)/8)*((u_p[i+1] + u_p[i])*((u_p[i+1])**2 - (u_p[i])**2)- (u_p[i] + u_p[i-1])*((u_p[i]**2) - (u_p[i-1])**2))
    
plot(x,u)
